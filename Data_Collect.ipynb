# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
movies = {
    'parasite' : 3,
    'suicide-squad' : 8,
    'birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn' : 3,
    'green-lantern' : 3,
    'transformers-revenge-of-the-fallen' : 8,
    'cats' : 2,
    'captain-marvel' : 21,
    'catwoman' : 1,
    'fifty-shades-of-grey' : 3,
    'frozen-2013': 4,
    'interstellar' : 8,
    'inception' : 11,
    'fantastic-four-2015' : 3,
    'logan-2017' : 4,
    'transformers-the-last-knight' : 2,
    'venom-2018' : 6,
    'transformers' : 6,
    'transformers-age-of-extinction' : 4,
    'transformers-dark-of-the-moon' : 4,
    'men-in-black-international' : 2,
    'joker' : 27,
    'titanic' : 2,
    'v-for-vendetta' : 4,
    'the-matrix' : 3,
    'the-dark-knight' : 15,
    'the-phantom-of-the-opera' : 1,
    'man-of-steel' : 11,
    'the-godfather' : 5,
    'justice-league' : 7,
    'whiplash' : 3,
    'la-la-land' : 3,
    'arrival' : 3,
    'blade-runner-2049' : 5,
    'gravity' : 8,
    'the-maze-runner' : 2,
    'ghostbusters-2016' : 5,
    'jack-and-jill' : 2,
    'the-emoji-movie' : 3,
    'after-earth' : 2,
    'ghost-rider' : 2,
    'twilight' : 4,
    'the-twilight-saga-new-moon' : 2,
    'the-twilight-saga-breaking-dawn---part-1' : 3,
    'the-dark-tower' : 2,
    'jupiter-ascending' : 2,
    'star-wars-episode-viii---the-last-jedi' : 42,
    'star-wars-episode-ix---the-rise-of-skywalker' : 24,
    'dark-phoenix' : 3,
    'star-wars-episode-vii---the-force-awakens' : 21,
    'epic-movie' : 2,
    'terminator-dark-fate' : 4,
    'dirty-grandpa' : 1,
    'the-human-centipede-first-sequence' : 1,
    'the-mummy-2017' : 2,
    'zoolander-2' : 1,
    'gods-of-egypt' : 2,
    'the-divergent-series-allegiant' : 1,
    'battlefield-earth-a-saga-of-the-year-3000' : 1,
    "fifty-shades-darker" : 1    
}

# %%
for movie_name in movies:
    totalPage = movies[movie_name]
    multi_page_result = [ ]
    for page in range( totalPage ):
        url = 'https://www.metacritic.com/movie/' + movie_name + '/user-reviews?page=' + str(page)

        html = requests.get( url, headers = { 'User-Agent' : 'Mozila/5.0' } )
        # Slow Down Error 뜨면 다시 get
        while ( str( html ) != '<Response [200]>' ):
            html = requests.get( url, headers = { 'User-Agent' : 'Mozila/5.0' } )
        soup = BeautifulSoup( html.text, 'html.parser' )

        # Get Reviews
        review_list = [ ]
        html_review_list = soup.findAll("div", attrs={"class":"review_body"})
        for div_line in html_review_list:
            span_list = div_line.find_all("span")
            for span_line in span_list:
                span_class = span_line.get("class")
                if not span_class:
                    text = span_line.get_text()
                    review_list.append(text.replace('\n\n', ''))
                elif len(span_class) > 1 and span_class[1]=='blurb_expanded':
                    text = span_line.get_text()
                    review_list.append(text.replace('\n\n', ''))

        # Get Label
        label_list = [ ]
        html_label_list = soup.select( 'div.metascore_w.user' )
        for line in html_label_list:
            label = line.attrs['class'][4]
            if label == 'negative':
                label_int = 0
            elif label == 'positive':
                label_int = 1
            elif label == 'mixed':
                label_int = 2
            label_list.append( label_int )
            
        for review, label in zip( review_list, label_list ):
            data = [ review, label ]
            multi_page_result.append( data )
            
        print( 'Success {} {}/{}'.format( movie_name, page + 1, totalPage ) )        
        
    review_df = pd.DataFrame( multi_page_result, columns = [ 'review', 'label' ] )
    
    review_df = review_df[review_df['label'] != 2] # Delete Mixed Review
    
    review_df.to_csv( 'Datas/' + movie_name + '_review.csv' )
    
    print( 'Crawling Success {}'.format( movie_name ), end = '\n\n' )
# Out:
# Success parasite 1/3
# Success parasite 2/3
# Success parasite 3/3
# Crawling Success parasite
#
# Success suicide-squad 1/8
# Success suicide-squad 2/8
# Success suicide-squad 3/8
# Success suicide-squad 4/8
# Success suicide-squad 5/8
# Success suicide-squad 6/8
# Success suicide-squad 7/8
# Success suicide-squad 8/8
# Crawling Success suicide-squad
#
# Success birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn 1/3
# Success birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn 2/3
# Success birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn 3/3
# Crawling Success birds-of-prey-and-the-fantabulous-emancipation-of-one-harley-quinn
#
# Success green-lantern 1/3
# Success green-lantern 2/3
# Success green-lantern 3/3
# Crawling Success green-lantern
#
# Success transformers-revenge-of-the-fallen 1/8
# Success transformers-revenge-of-the-fallen 2/8
# Success transformers-revenge-of-the-fallen 3/8
# Success transformers-revenge-of-the-fallen 4/8
# Success transformers-revenge-of-the-fallen 5/8
# Success transformers-revenge-of-the-fallen 6/8
# Success transformers-revenge-of-the-fallen 7/8
# Success transformers-revenge-of-the-fallen 8/8
# Crawling Success transformers-revenge-of-the-fallen
#
# Success cats 1/2
# Success cats 2/2
# Crawling Success cats
#
# Success captain-marvel 1/21
# Success captain-marvel 2/21
# Success captain-marvel 3/21
# Success captain-marvel 4/21
# Success captain-marvel 5/21
# Success captain-marvel 6/21
# Success captain-marvel 7/21
# Success captain-marvel 8/21
# Success captain-marvel 9/21
# Success captain-marvel 10/21
# Success captain-marvel 11/21
# Success captain-marvel 12/21
# Success captain-marvel 13/21
# Success captain-marvel 14/21
# Success captain-marvel 15/21
# Success captain-marvel 16/21
# Success captain-marvel 17/21
# Success captain-marvel 18/21
# Success captain-marvel 19/21
# Success captain-marvel 20/21
# Success captain-marvel 21/21
# Crawling Success captain-marvel
#
# Success catwoman 1/1
# Crawling Success catwoman
#
# Success fifty-shades-of-grey 1/3
# Success fifty-shades-of-grey 2/3
# Success fifty-shades-of-grey 3/3
# Crawling Success fifty-shades-of-grey
#
# Success frozen-2013 1/4
# Success frozen-2013 2/4
# Success frozen-2013 3/4
# Success frozen-2013 4/4
# Crawling Success frozen-2013
#
# Success interstellar 1/8
# Success interstellar 2/8
# Success interstellar 3/8
# Success interstellar 4/8
# Success interstellar 5/8
# Success interstellar 6/8
# Success interstellar 7/8
# Success interstellar 8/8
# Crawling Success interstellar
#
# Success inception 1/11
# Success inception 2/11
# Success inception 3/11
# Success inception 4/11
# Success inception 5/11
# Success inception 6/11
# Success inception 7/11
# Success inception 8/11
# Success inception 9/11
# Success inception 10/11
# Success inception 11/11
# Crawling Success inception
#
# Success fantastic-four-2015 1/3
# Success fantastic-four-2015 2/3
# Success fantastic-four-2015 3/3
# Crawling Success fantastic-four-2015
#
# Success logan-2017 1/4
# Success logan-2017 2/4
# Success logan-2017 3/4
# Success logan-2017 4/4
# Crawling Success logan-2017
#
# Success transformers-the-last-knight 1/2
# Success transformers-the-last-knight 2/2
# Crawling Success transformers-the-last-knight
#
# Success venom-2018 1/6
# Success venom-2018 2/6
# Success venom-2018 3/6
# Success venom-2018 4/6
# Success venom-2018 5/6
# Success venom-2018 6/6
# Crawling Success venom-2018
#
# Success transformers 1/6
# Success transformers 2/6
# Success transformers 3/6
# Success transformers 4/6
# Success transformers 5/6
# Success transformers 6/6
# Crawling Success transformers
#
# Success transformers-age-of-extinction 1/4
# Success transformers-age-of-extinction 2/4
# Success transformers-age-of-extinction 3/4
# Success transformers-age-of-extinction 4/4
# Crawling Success transformers-age-of-extinction
#
# Success transformers-dark-of-the-moon 1/4
# Success transformers-dark-of-the-moon 2/4
# Success transformers-dark-of-the-moon 3/4
# Success transformers-dark-of-the-moon 4/4
# Crawling Success transformers-dark-of-the-moon
#
# Success men-in-black-international 1/2
# Success men-in-black-international 2/2
# Crawling Success men-in-black-international
#
# Success joker 1/27
# Success joker 2/27
# Success joker 3/27
# Success joker 4/27
# Success joker 5/27
# Success joker 6/27
# Success joker 7/27
# Success joker 8/27
# Success joker 9/27
# Success joker 10/27
# Success joker 11/27
# Success joker 12/27
# Success joker 13/27
# Success joker 14/27
# Success joker 15/27
# Success joker 16/27
# Success joker 17/27
# Success joker 18/27
# Success joker 19/27
# Success joker 20/27
# Success joker 21/27
# Success joker 22/27
# Success joker 23/27
# Success joker 24/27
# Success joker 25/27
# Success joker 26/27
# Success joker 27/27
# Crawling Success joker
#
# Success titanic 1/2
# Success titanic 2/2
# Crawling Success titanic
#
# Success v-for-vendetta 1/4
# Success v-for-vendetta 2/4
# Success v-for-vendetta 3/4
# Success v-for-vendetta 4/4
# Crawling Success v-for-vendetta
#
# Success the-matrix 1/3
# Success the-matrix 2/3
# Success the-matrix 3/3
# Crawling Success the-matrix
#
# Success the-dark-knight 1/15
# Success the-dark-knight 2/15
# Success the-dark-knight 3/15
# Success the-dark-knight 4/15
# Success the-dark-knight 5/15
# Success the-dark-knight 6/15
# Success the-dark-knight 7/15
# Success the-dark-knight 8/15
# Success the-dark-knight 9/15
# Success the-dark-knight 10/15
# Success the-dark-knight 11/15
# Success the-dark-knight 12/15
# Success the-dark-knight 13/15
# Success the-dark-knight 14/15
# Success the-dark-knight 15/15
# Crawling Success the-dark-knight
#
# Success the-phantom-of-the-opera 1/1
# Crawling Success the-phantom-of-the-opera
#
# Success man-of-steel 1/11
# Success man-of-steel 2/11
# Success man-of-steel 3/11
# Success man-of-steel 4/11
# Success man-of-steel 5/11
# Success man-of-steel 6/11
# Success man-of-steel 7/11
# Success man-of-steel 8/11
# Success man-of-steel 9/11
# Success man-of-steel 10/11
# Success man-of-steel 11/11
# Crawling Success man-of-steel
#
# Success the-godfather 1/5
# Success the-godfather 2/5
# Success the-godfather 3/5
# Success the-godfather 4/5
# Success the-godfather 5/5
# Crawling Success the-godfather
#
# Success justice-league 1/7
# Success justice-league 2/7
# Success justice-league 3/7
# Success justice-league 4/7
# Success justice-league 5/7
# Success justice-league 6/7
# Success justice-league 7/7
# Crawling Success justice-league
#
# Success whiplash 1/3
# Success whiplash 2/3
# Success whiplash 3/3
# Crawling Success whiplash
#
# Success la-la-land 1/3
# Success la-la-land 2/3
# Success la-la-land 3/3
# Crawling Success la-la-land
#
# Success arrival 1/3
# Success arrival 2/3
# Success arrival 3/3
# Crawling Success arrival
#
# Success blade-runner-2049 1/5
# Success blade-runner-2049 2/5
# Success blade-runner-2049 3/5
# Success blade-runner-2049 4/5
# Success blade-runner-2049 5/5
# Crawling Success blade-runner-2049
#
# Success gravity 1/8
# Success gravity 2/8
# Success gravity 3/8
# Success gravity 4/8
# Success gravity 5/8
# Success gravity 6/8
# Success gravity 7/8
# Success gravity 8/8
# Crawling Success gravity
#
# Success the-maze-runner 1/2
# Success the-maze-runner 2/2
# Crawling Success the-maze-runner
#
# Success ghostbusters-2016 1/5
# Success ghostbusters-2016 2/5
# Success ghostbusters-2016 3/5
# Success ghostbusters-2016 4/5
# Success ghostbusters-2016 5/5
# Crawling Success ghostbusters-2016
#
# Success jack-and-jill 1/2
# Success jack-and-jill 2/2
# Crawling Success jack-and-jill
#
# Success the-emoji-movie 1/3
# Success the-emoji-movie 2/3
# Success the-emoji-movie 3/3
# Crawling Success the-emoji-movie
#
# Success after-earth 1/2
# Success after-earth 2/2
# Crawling Success after-earth
#
# Success ghost-rider 1/2
# Success ghost-rider 2/2
# Crawling Success ghost-rider
#
# Success twilight 1/4
# Success twilight 2/4
# Success twilight 3/4
# Success twilight 4/4
# Crawling Success twilight
#
# Success the-twilight-saga-new-moon 1/2
# Success the-twilight-saga-new-moon 2/2
# Crawling Success the-twilight-saga-new-moon
#
# Success the-twilight-saga-breaking-dawn---part-1 1/3
# Success the-twilight-saga-breaking-dawn---part-1 2/3
# Success the-twilight-saga-breaking-dawn---part-1 3/3
# Crawling Success the-twilight-saga-breaking-dawn---part-1
#
# Success the-dark-tower 1/2
# Success the-dark-tower 2/2
# Crawling Success the-dark-tower
#
# Success jupiter-ascending 1/2
# Success jupiter-ascending 2/2
# Crawling Success jupiter-ascending
#
# Success star-wars-episode-viii---the-last-jedi 1/42
